# %% [markdown]
# <a href="https://colab.research.google.com/github/bidin485/RAG-TRY-OUTS/blob/main/Building_a_RAG_App_on_GCP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# A quick start guide for building a RAG application on Google Cloud,
# adapted for use in a Google Colab notebook.
# This code demonstrates the core steps from environment setup to a complete query.
# Before running this code, ensure you have a Google Cloud project with
# the Vertex AI API enabled.

# --- 1. SETUP FOR COLAB ---
# Install the necessary libraries in your Colab environment.
# The `!` prefix allows you to run shell commands directly from the notebook.
# !pip install --upgrade google-cloud-aiplatform google-cloud-storage

# Authenticate with Google Cloud using your user account.
# This command will open a new browser tab for you to log in.
from google.colab import auth
auth.authenticate_user()

# Import the vertexai library
import vertexai

# --- 2. CONFIGURATION ---
# Define your Google Cloud project details.
PROJECT_ID = "text-to-speech-test-469811"  # Your project ID
LOCATION = "us-west1"       # Your desired region, e.g., "us-east4"
BUCKET_NAME = "trying-out-things-bucket" # Your Cloud Storage bucket name
GCS_FOLDER_PATH = "Software Engineering/" # Path to your folder
CORPUS_DISPLAY_NAME = "my-rag-corpus"

# Set the project and initialize the Vertex AI SDK.
# The `gcloud` command sets the active project for the session.
# !gcloud config set project {PROJECT_ID}

print("Initializing Vertex AI...")
vertexai.init(project=PROJECT_ID, location=LOCATION)

# --- 3.A DYNAMIC FILE LISTING (RECURSIVE) ---
# Use the Google Cloud Storage client to get a list of all files recursively
# within the specified folder and all its subfolders.
try:
    print(f"Listing files recursively in folder 'gs://{BUCKET_NAME}/{GCS_FOLDER_PATH}'...")
    from google.cloud import storage
    storage_client = storage.Client(project=PROJECT_ID)
    bucket = storage_client.bucket(BUCKET_NAME)

    # The `list_blobs` function is recursive by default. It will find all files
    # that start with the specified prefix, traversing all subdirectories.
    blobs = bucket.list_blobs(prefix=GCS_FOLDER_PATH)

    GCS_FILE_PATHS = []
    for blob in blobs:
        # We only want to add files, not subdirectories or the folder itself.
        if not blob.name.endswith('/'):
            file_path = f"gs://{BUCKET_NAME}/{blob.name}"
            GCS_FILE_PATHS.append(file_path)
            print(f"  Found: {file_path}")  # Show the path as it's found

    if not GCS_FILE_PATHS:
        raise ValueError("No files found in the specified folder. Please check your folder path.")

    print(f"Found a total of {len(GCS_FILE_PATHS)} files to import.")

except Exception as e:
    print(f"An error occurred while listing files: {e}")
    # Exit or handle the error gracefully if no files are found.
    # For this example, we'll stop the script.
    # A Colab-friendly way to stop execution is to raise an error.
    raise RuntimeError("Script stopped due to file listing error.") from e

# --- 3.B CORPUS CREATION & DATA INGESTION ---
# This step creates a new RAG corpus and imports your documents from the dynamically generated list.
# The RAG Engine automatically handles chunking and embedding generation.
# This process can take a few minutes depending on the size of your documents.
from vertexai import rag
try:
    print(f"Creating a new RAG Corpus named '{CORPUS_DISPLAY_NAME}'...")
    rag_corpus = rag.create_corpus(
        display_name=CORPUS_DISPLAY_NAME
    )
    print(f"Corpus created with resource name: {rag_corpus.name}")

    print("Importing files from Cloud Storage...")
    import_op = rag.import_files(
        rag_corpus.name,
        GCS_FILE_PATHS,
        # Transformation config is optional, but good for tuning chunking.
        transformation_config=rag.TransformationConfig(
            chunking_config=rag.ChunkingConfig(
                chunk_size=512,
                chunk_overlap=100,
            ),
        ),
    )
    import_op.result()  # Wait for the import to complete.
    print("Files imported successfully. Indexing is complete.")

except Exception as e:
    print(f"An error occurred during corpus creation or file import: {e}")
    # You might want to get an existing corpus if it already exists.
    # To use an existing corpus, you can use `rag.get_corpus(name="projects/...")`
    raise RuntimeError("Script stopped due to corpus creation/import error.") from e


# --- 4. RETRIEVAL & GENERATION ---
# This is the real-time part of the RAG application.
# 4a. Create a RAG retrieval tool based on the corpus.
from vertexai.generative_models import GenerativeModel, Tool

rag_retrieval_tool = Tool.from_retrieval(
    retrieval=rag.Retrieval(
        source=rag.VertexRagStore(
            rag_resources=[
                rag.RagResource(
                    rag_corpus=rag_corpus.name
                )
            ],
        ),
    )
)

# 4b. Create a Gemini model instance and pass the tool to it.
# The model will use this tool to "look up" information from your corpus.
model = GenerativeModel(
    model_name="gemini-2.0-flash-001",
    tools=[rag_retrieval_tool]
)

# 4c. Formulate a user query and generate a response.
user_query = "Summarize the key takeaways from the documents."
print(f"\nSending query to Gemini: '{user_query}'...")

# The model will automatically use the tool to find relevant context
# before generating the final, grounded response.
response = model.generate_content(user_query)

# Print the final response from the model.
print("\n--- GENERATED RESPONSE ---")
print(response.text)
print("--------------------------")
# Out:
# Requirement already satisfied: google-cloud-aiplatform in /usr/local/lib/python3.12/dist-packages (1.110.0)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Collecting google-cloud-storage
#   Using cached google_cloud_storage-3.3.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (2.25.1)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (2.38.0)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (1.26.1)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.20.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (5.29.5)
# Requirement already satisfied: packaging>=14.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (25.0)
# Requirement already satisfied: google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (3.35.1)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0,>=1.3.3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (1.14.2)
# Requirement already satisfied: shapely<3.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (2.1.1)
# Requirement already satisfied: google-genai<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (1.30.0)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (2.11.7)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (4.14.1)
# Requirement already satisfied: docstring_parser<1 in /usr/local/lib/python3.12/dist-packages (from google-cloud-aiplatform) (0.17.0)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.7.2)
# Requirement already satisfied: requests<3.0.0dev,>=2.18.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (2.32.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-storage) (1.7.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.70.0)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.74.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.12/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0,>=1.34.1->google-cloud-aiplatform) (1.71.2)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (4.9.1)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (2.9.0.post0)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0,>=0.14.0 in /usr/local/lib/python3.12/dist-packages (from google-cloud-resource-manager<3.0.0,>=1.3.3->google-cloud-aiplatform) (0.14.2)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (4.10.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (0.28.1)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (8.5.0)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (15.0.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->google-cloud-aiplatform) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3->google-cloud-aiplatform) (0.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0dev,>=2.18.0->google-cloud-storage) (2025.8.3)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.12/dist-packages (from shapely<3.0.0->google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.3.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.0.0->google-cloud-aiplatform) (0.16.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-cloud-aiplatform) (0.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.2->google-cloud-bigquery!=3.20.0,<4.0.0,>=1.15.0->google-cloud-aiplatform) (1.17.0)
# Updated property [core/project].
# Initializing Vertex AI...
# Listing files recursively in folder 'gs://trying-out-things-bucket/Software Engineering/'...
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester  2/exams/big data and cloud computing test.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester  2/exams/research methodology exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester  2/exams/research_methodology test.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester  2/exams/software architecture and patterns exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester  2/exams/software evolution exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester  2/exams/software testing and verification exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester 1/exams/UI test 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester 1/exams/UID exam 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester 1/exams/embedded systems 1 test 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester 1/exams/embedded_systems1 exam 2025 .pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester 1/exams/software evolution exam 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 3/semester 1/exams/software metrics 2025 exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/exams/IEE exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/exams/deployment and integration_exam 2024.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/exams/emerging trends exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/6. Microservices architecture.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI-1.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI-2.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI-3.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI-4.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI-5.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI-6.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/AI_sample_questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/BlockChain.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Blockchain_Sample_questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Capstone Project-BSE4101 Emerging Trends in Software Engineering.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Capstone Work_BSE-14.zip
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Chapter_one_Improved.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/DevOps.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Edge Computing.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Final Project Report(WEEK 5)_ CI_CD Pipeline for Property Tracking System.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Introduction to Emerging Trends in Computing.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Lecture 3- DevOps and Code Management.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Microservices_Sample_Questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Property Tracking System CI_CD Documentation.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Property Tracking System Powerpoint.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Quantum_computing_sample_questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Sample_questions_(DevOps).pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Summary Report Week 1-2024101811175025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Summary Report Week 2-2024101811180561.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Summary Report Week 3-2024101811182556.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/Summary Report Week 4-2024101811232430.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/microservices.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/EMERGING TRENDS IN SOFTWARE ENGINEERING/quantum.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/ICT INNOVATION AND ENTREPRENEURSHIP/Assignment-1-ICT Innovations.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/ICT INNOVATION AND ENTREPRENEURSHIP/ICT-EBM.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/ICT INNOVATION AND ENTREPRENEURSHIP/IIE-1.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/ICT INNOVATION AND ENTREPRENEURSHIP/IIE-2.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/ICT INNOVATION AND ENTREPRENEURSHIP/IIE-3.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/ICT INNOVATION AND ENTREPRENEURSHIP/~$signment-1-ICT Innovations.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/BSE 4105 Project.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/CD.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/CI.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 01.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 02.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 03.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 04.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 05.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 06 (Docker).docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 07 (CICD with GitLab)_00.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/Exercise 07 (CICD with GitLab)_01.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/homework5.sh
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/hw1.zip
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/hw2.zip
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Coursework/~$ercise 05.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Introduction-00.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Linux Fundamentals.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Microservices  Containerisation.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 1/notes/SOFTWARE INTEGRATION AND DEPLOYEMENT/Version Control with Git - AM.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/exams/software Quality management Exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/exams/software ethics exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/exams/sofware security exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/16_EBOOK-7th_ed_software_engineering_a_practitioners_approach_by_roger_s._pressman_.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/2. Assignment 2, 8jobspot.com -Computer Security (1).docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/2. Assignment 2, 8jobspot.com -Computer Security.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/AREAS.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/B answered.xlsx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/LT11_Traciability analysis.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/LT16_Software Configuration Management.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/Software Engineering - Ian Sommerville 10th edition.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/Software Quality Assurance From Theory to Implementation.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/lecture 6_ process quality_muele.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/quality_summary.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/reading resources.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/recording links.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software Quality/topic two reading guidelines.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/1.introduction_and_definitions_0_0[1].pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Assignment BSE4203-Software Eningeering Standards and Ethics.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Ethics in Information Technology (Reynolds, George) (Z-Library).pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Extended Discussion Notes.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/IP Notes.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lect 2.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lecture 1.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lecture 1.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lecture 3.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lecture 3.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lecture 5.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/Lectures 8 and 9 Notes.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/chapter 10-21.zip
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/lecture 4.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software ethics/swebok-v3.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/1. Software Quality Assurance From Theory to Implementation-Main book.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/2. Cross Site Scripting.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/2. Cross Site Scripting.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/24-DEADLY-SINS-OF-SOFTWARE-SECURITY-2010.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/Alanda_summary.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/ISO-IEC_27002-.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/LT0_ Software Security Introduction_2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/LT10_  Information Security Frameworks Feb 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/LT11_  DiD SSOA Digital Forensics- Feb 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/LT13_ Software Security  IT Audit Marc 2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/LT1_Software Security Security  Authentication_2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/LT2_  Mobile App Testing and Quality Assurance_2025.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/NIST.CSWP.29.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/NOTES.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/NOTES.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/National-Cybersecurity-Strategy-UG.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/SQL-Injection.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/Sandboxing in Computer Security.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/chap1-Cryptograph.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/notes/software security/sql Injection.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/tests/Software Security Test.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/tests/ethics test.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/tests/software Quality management test 2.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/Year 4/semester 2/tests/software quality management test 1.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/1.Sets.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Axioms-Definitions-and-Proofs-01-02-18.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/DiscMaths4CompSc.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Discreet maths.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Discrete Mathematics.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Discrete_Mathematics___MTH1101_-_Lecture_2_-_Basic_Logic_Operations.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Functions.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/MATHEMATICAL STRACTURES .pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Predicate Logic.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Propositional Logic.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Relations.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/Sets.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/dmbook.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/lect07.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 1/semester 1/notes/MATHEMATICS FOR SOFTWARE ENGINEERS/usingz.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/AI-Final-23.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/AI_Russell_Norvig.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Assignment CS2114.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Baye nets questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/CSC 2114-Marking guide-2016.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/CSP PROBLEMS.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/CsC2114 -Reinforcement learning  introduction.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 1-Introduction.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 10 -- Naive Bayes.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 10-Decision networks.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 11 -- Perceptron.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 11-MDPS.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 12 -- Kernels and Clustering.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 12-reinforcement learning.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 2-Uninformed Search.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 3- Informed Search.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 4-Local Search.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 5-Adversarial Search.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 6-Adversarial Search 11.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 7-Introduction to Preposition Logic.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 8 -- Probability.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 8-Inference in logic.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 8-Planning.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Lecture 9 -- Bayes Nets.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Naive bayes questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Perceptron questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Quiz 1_ Introduction, Search and CSPS_ Attempt review _ MUELE.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/Search problems.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/WhatsApp Image 2024-11-25 at 18.05.17_e9d240e8.jpg
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/aipython.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/cat1-Marking-guide-2016.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/cat1-marking Guide.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/cs188_sp10_mt1.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/gameplaying.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/probabiltiy_exercise.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/~$Lecture 2-Uninformed Search.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/~$Lecture 5-Adversarial Search.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/ARTIFICIAL INTELLIGENCE/~$Lecture 6-Adversarial Search 11.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Chapter_10_Media (physical Layer) (1).pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Chapter_1_V6.1.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Chapter_2_ Standards  Protocals.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Chapter_3_V6.01.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Chapter_4_TransportLayer.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Chapter_5_ Network Layer.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Comp Networks Tests and book solns.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Computer Networking _ A Top Down Approach, 7th, converted.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/Network security for group C evening[1].pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/UX Writing ELP Presentation.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/computer networks Combined past papers.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/COMPUTER NETWORKS/~$Network security for group C evening[1].pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/DSA-test1-Answers.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/DSA.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture1 Introduction.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture10 Hashing.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture2 Data Structure Concepts.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture3 Linked List.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture4 Stack and Queues.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture5 Algorithms.ppt
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture6 Asymptotic Notations.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture7 Design Strategies_ divide and conquer and greedy.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture8 Trees Binary tree.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/Lecture9 Sorting algorithms.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/~$A Class Assignments.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/~$Lecture2 Data Structure Concepts.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/~$Lecture4 Stack and Queues.pptx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/~$acks and queues.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/DATA STRUCTURES AND ALGORITHMS/~WRL0161.tmp
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/BSE2105_Formal_Methods[2].pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/Course Work BSE 2105.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/FORMAL METHODS FINAL EXAM 2105.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/FORMAL METHODS Test 1 Soln.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/FORMAL METHODS Test_1.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/FORMAL METHODS _.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/Formal methods.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/Proposed_Test2 Answers.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Exam/formal_methodsTEST1.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Formal Proof, Understanding, writing and evaluating proofs.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Formal methods Group I and J.docx
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Formal-Methods-test-1-22.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Formal_Methods_Proposed_test2_Questions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Functions-recap.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture 3 Propositional Logic.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture 5 Functions.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture 6 Predicate Logic.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture 7 Introduction to Z(Zed).pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture 8 Bags(2).pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture3 - Relations .pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture4-Predicates.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture5-EventB_Notation.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Lecture_3-Relations.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Meeting Summary for Formal Methods Online Class.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Methods of prrof.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Proposed_Test2 Answers.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Review-of-set-theory.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/Rodin book.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 1/notes/FORMAL METHODS/eventb-dbook13.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/2024[1].pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/OPERATING SYSTEMS TEST2 Marking Guide (0).pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/OS Examination 2019-2020 Moderated.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/OS qsn.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/OS.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/Operating System Passed Exam Paper.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/OS_exams/Operating systems[1].pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/data communications exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/data communications test.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/emerging web technologies exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/mobile programming project exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/operating systems exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/operation systems 2 exam.pdf
#   Found: gs://trying-out-things-bucket/Software Engineering/year 2/semester 2/exams/requirements engineering exam.pdf
# Found a total of 251 files to import.
# Creating a new RAG Corpus named 'my-rag-corpus'...
# An error occurred during corpus creation or file import: ('Failed in RagCorpus creation due to: ', FailedPrecondition('Vertex AI Rag Service is not supported in region us-west1'))
# ---------------------------------------------------------------------------
# _InactiveRpcError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      75         try:
# ---> 76             return callable_(*args, **kwargs)
#      77         except grpc.RpcError as exc:
#
# /usr/local/lib/python3.12/dist-packages/grpc/_interceptor.py in __call__(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     276     ) -> Any:
# --> 277         response, ignored_call = self._with_call(
#     278             request,
#
# /usr/local/lib/python3.12/dist-packages/grpc/_interceptor.py in _with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#     331         )
# --> 332         return call.result(), call
#     333
#
# /usr/local/lib/python3.12/dist-packages/grpc/_channel.py in result(self, timeout)
#     439         """See grpc.Future.result."""
# --> 440         raise self
#     441
#
# /usr/local/lib/python3.12/dist-packages/grpc/_interceptor.py in continuation(new_details, request)
#     314             try:
# --> 315                 response, call = self._thunk(new_method).with_call(
#     316                     request,
#
# /usr/local/lib/python3.12/dist-packages/grpc/_channel.py in with_call(self, request, timeout, metadata, credentials, wait_for_ready, compression)
#    1191         )
# -> 1192         return _end_unary_response_blocking(state, call, True, None)
#    1193
#
# /usr/local/lib/python3.12/dist-packages/grpc/_channel.py in _end_unary_response_blocking(state, call, with_call, deadline)
#    1005     else:
# -> 1006         raise _InactiveRpcError(state)  # pytype: disable=not-instantiable
#    1007
#
# _InactiveRpcError: <_InactiveRpcError of RPC that terminated with:
# 	status = StatusCode.FAILED_PRECONDITION
# 	details = "Vertex AI Rag Service is not supported in region us-west1"
# 	debug_error_string = "UNKNOWN:Error received from peer ipv4:74.125.196.95:443 {grpc_message:"Vertex AI Rag Service is not supported in region us-west1", grpc_status:9}"
# >
#
# The above exception was the direct cause of the following exception:
#
# FailedPrecondition                        Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/vertexai/rag/rag_data.py in create_corpus(display_name, description, vertex_ai_search_config, backend_config, encryption_spec, timeout)
#     148     try:
# --> 149         response = client.create_rag_corpus(request=request)
#     150     except Exception as e:
#
# /usr/local/lib/python3.12/dist-packages/google/cloud/aiplatform_v1/services/vertex_rag_data_service/client.py in create_rag_corpus(self, request, parent, rag_corpus, retry, timeout, metadata)
#     997         # Send the request.
# --> 998         response = rpc(
#     999             request,
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/gapic_v1/method.py in __call__(self, timeout, retry, compression, *args, **kwargs)
#     130
# --> 131         return wrapped_func(*args, **kwargs)
#     132
#
# /usr/local/lib/python3.12/dist-packages/google/api_core/grpc_helpers.py in error_remapped_callable(*args, **kwargs)
#      77         except grpc.RpcError as exc:
# ---> 78             raise exceptions.from_grpc_error(exc) from exc
#      79
#
# FailedPrecondition: 400 Vertex AI Rag Service is not supported in region us-west1
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3605539647.py in <cell line: 0>()
#      74     print(f"Creating a new RAG Corpus named '{CORPUS_DISPLAY_NAME}'...")
# ---> 75     rag_corpus = rag.create_corpus(
#      76         display_name=CORPUS_DISPLAY_NAME
#
# /usr/local/lib/python3.12/dist-packages/vertexai/rag/rag_data.py in create_corpus(display_name, description, vertex_ai_search_config, backend_config, encryption_spec, timeout)
#     150     except Exception as e:
# --> 151         raise RuntimeError("Failed in RagCorpus creation due to: ", e) from e
#     152     return _gapic_utils.convert_gapic_to_rag_corpus(response.result(timeout=timeout))
#
# RuntimeError: ('Failed in RagCorpus creation due to: ', FailedPrecondition('Vertex AI Rag Service is not supported in region us-west1'))
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3605539647.py in <cell line: 0>()
#      97     # You might want to get an existing corpus if it already exists.
#      98     # To use an existing corpus, you can use `rag.get_corpus(name="projects/...")`
# ---> 99     raise RuntimeError("Script stopped due to corpus creation/import error.") from e
#     100
#     101
#
# RuntimeError: Script stopped due to corpus creation/import error.
